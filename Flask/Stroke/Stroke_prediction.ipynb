# %% [markdown]
# ## 참고: https://hleecaster.com/ml-linear-regression-example/

# %% [markdown]
# ## 라이브러리 설치, 호출

# %% [markdown]
# !pip3 install -U scikit-learn<br>
# !pip3 install pandas<br>
# !pip3 install numpy<br>
# !pip3 install matplotlib<br>
# !pip3 install statsmodels<br>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau

# %% [markdown]
# ## 기본적인 데이터 처리 (정보 확인, 결측치 처리, Drop)

# %%
import pandas as pd
df = pd.read_csv('/Users/krc/Downloads/healthcare-dataset-stroke-data.csv')
print(df.head())
print(df.shape)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# (5110, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df[df.dtypes[df.dtypes == 'object'].index].columns
# Out:
# Index(['gender', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
# 데이터 결측치 개수 확인
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# 결측치 drop
df = df.dropna()

# %%
# 중복 제거하고 unique 값 확인 -> Other 값 확인
df['gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
# gender == Other인 인덱스 값 불러오고 drop 
idx = df[df['gender'] == 'Other'].index
df.drop(idx, inplace = True)

# %%
# drop된 데이터 확인
df['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ## 데이터 encoding 처리

# %%
# label encoding
import numpy as np
from sklearn.preprocessing import LabelEncoder

# Label Encoder 선언 및 Fitting
en = LabelEncoder()
en.fit(df.gender)

# gender 변환 
df.gender = en.transform(df.gender)

# %%
df.gender
# Out:
# 0       1
# 2       1
# 3       0
# 4       0
# 5       1
#        ..
# 5104    0
# 5106    0
# 5107    0
# 5108    1
# 5109    0
# Name: gender, Length: 4908, dtype: int64

# %%
#  ever_married, smoking_status 변환
df.loc[:,['ever_married', 'smoking_status']] = df.loc[:,['ever_married', 'smoking_status']].apply(en.fit_transform)

# %%
df.loc[:,['ever_married', 'smoking_status']]
# Out:
#       ever_married  smoking_status
# 0                1               1
# 2                1               2
# 3                1               3
# 4                1               2
# 5                1               1
# ...            ...             ...
# 5104             0               0
# 5106             1               2
# 5107             1               2
# 5108             1               1
# 5109             1               0
#
# [4908 rows x 2 columns]

# %% [markdown]
# ## Input, Feature 설정

# %%
Label = df['stroke']
InputFeature = df[["gender", "age", "hypertension", "heart_disease", 
                    "ever_married","avg_glucose_level", "bmi", "smoking_status"]]

# %%
InputFeature.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0       1  67.0             0              1             1             228.69
# 2       1  80.0             0              1             1             105.92
# 3       0  49.0             0              0             1             171.23
# 4       0  79.0             1              0             1             174.12
# 5       1  81.0             0              0             1             186.21
#
#     bmi  smoking_status
# 0  36.6               1
# 2  32.5               2
# 3  34.4               3
# 4  24.0               2
# 5  29.0               1

# %% [markdown]
# ## Keras Logit 모델 fitting

# %%
model = Sequential()
model.add(Dense(5, activation='linear', input_shape=(8,) ))
model.add(Dense(10, activation='linear'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])

# %% [markdown]
# ## Keras 모델 살펴보기

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 45
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 116
# Trainable params: 116
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Call-back 함수
# ## 모델 학습

# %%
# Call-back 함수
# CheckPoint: Epoch 마다 validation 성능을 검증하여, best performance 일 경우 저장
CP = ModelCheckpoint(filepath='Models/{epoch:03d}-{loss:.4f}-{accuracy:.4f}.hdf5',
            monitor='loss', verbose=1, save_best_only=True, mode='min')

# Learning Rate 줄여나가기
LR = ReduceLROnPlateau(monitor='loss',factor=0.8,patience=3, verbose=1, min_lr=1e-8)

CALLBACK = [CP, LR]

# %%
model.fit(x=InputFeature, y=Label, epochs=100, shuffle=True, batch_size=3, callbacks=CALLBACK)
# Out:
# Epoch 1/100
#    1/1636 [..............................] - ETA: 3:57 - loss: 1.8003 - accuracy: 0.6667
# 2022-07-19 20:01:26.319170: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1544/1636 [===========================>..] - ETA: 0s - loss: 0.2874 - accuracy: 0.9484
# Epoch 1: loss improved from inf to 0.28341, saving model to Models/001-0.2834-0.9489.hdf5
# 1636/1636 [==============================] - 1s 401us/step - loss: 0.2834 - accuracy: 0.9489 - lr: 0.0100
# Epoch 2/100
# 1606/1636 [============================>.] - ETA: 0s - loss: 0.1826 - accuracy: 0.9541
# Epoch 2: loss improved from 0.28341 to 0.18409, saving model to Models/002-0.1841-0.9533.hdf5
# 1636/1636 [==============================] - 1s 351us/step - loss: 0.1841 - accuracy: 0.9533 - lr: 0.0100
# Epoch 3/100
# 1587/1636 [============================>.] - ETA: 0s - loss: 0.1692 - accuracy: 0.9557
# Epoch 3: loss improved from 0.18409 to 0.17220, saving model to Models/003-0.1722-0.9546.hdf5
# 1636/1636 [==============================] - 1s 320us/step - loss: 0.1722 - accuracy: 0.9546 - lr: 0.0100
# Epoch 4/100
# 1515/1636 [==========================>...] - ETA: 0s - loss: 0.1645 - accuracy: 0.9556
# Epoch 4: loss improved from 0.17220 to 0.16299, saving model to Models/004-0.1630-0.9556.hdf5
# 1636/1636 [==============================] - 1s 335us/step - loss: 0.1630 - accuracy: 0.9556 - lr: 0.0100
# Epoch 5/100
# 1493/1636 [==========================>...] - ETA: 0s - loss: 0.1673 - accuracy: 0.9562
# Epoch 5: loss did not improve from 0.16299
# 1636/1636 [==============================] - 0s 304us/step - loss: 0.1668 - accuracy: 0.9562 - lr: 0.0100
# Epoch 6/100
# 1572/1636 [===========================>..] - ETA: 0s - loss: 0.1652 - accuracy: 0.9546
# Epoch 6: loss improved from 0.16299 to 0.16235, saving model to Models/006-0.1623-0.9556.hdf5
# 1636/1636 [==============================] - 1s 325us/step - loss: 0.1623 - accuracy: 0.9556 - lr: 0.0100
# Epoch 7/100
# 1519/1636 [==========================>...] - ETA: 0s - loss: 0.1664 - accuracy: 0.9546
# Epoch 7: loss did not improve from 0.16235
# 1636/1636 [==============================] - 0s 298us/step - loss: 0.1653 - accuracy: 0.9546 - lr: 0.0100
# Epoch 8/100
# 1507/1636 [==========================>...] - ETA: 0s - loss: 0.1619 - accuracy: 0.9566
# Epoch 8: loss improved from 0.16235 to 0.16142, saving model to Models/008-0.1614-0.9568.hdf5
# 1636/1636 [==============================] - 0s 304us/step - loss: 0.1614 - accuracy: 0.9568 - lr: 0.0100
# Epoch 9/100
# 1617/1636 [============================>.] - ETA: 0s - loss: 0.1665 - accuracy: 0.9559
# Epoch 9: loss did not improve from 0.16142
# 1636/1636 [==============================] - 1s 313us/step - loss: 0.1667 - accuracy: 0.9558 - lr: 0.0100
# Epoch 10/100
# 1603/1636 [============================>.] - ETA: 0s - loss: 0.1632 - accuracy: 0.9557
# Epoch 10: loss did not improve from 0.16142
# 1636/1636 [==============================] - 1s 313us/step - loss: 0.1629 - accuracy: 0.9560 - lr: 0.0100
# Epoch 11/100
# 1507/1636 [==========================>...] - ETA: 0s - loss: 0.1611 - accuracy: 0.9549
# Epoch 11: loss improved from 0.16142 to 0.15798, saving model to Models/011-0.1580-0.9558.hdf5
# 1636/1636 [==============================] - 0s 305us/step - loss: 0.1580 - accuracy: 0.9558 - lr: 0.0100
# Epoch 12/100
# 1554/1636 [===========================>..] - ETA: 0s - loss: 0.1678 - accuracy: 0.9558
# Epoch 12: loss did not improve from 0.15798
# 1636/1636 [==============================] - 1s 322us/step - loss: 0.1677 - accuracy: 0.9554 - lr: 0.0100
# Epoch 13/100
# 1594/1636 [============================>.] - ETA: 0s - loss: 0.1560 - accuracy: 0.9559
# Epoch 13: loss did not improve from 0.15798
# 1636/1636 [==============================] - 1s 346us/step - loss: 0.1591 - accuracy: 0.9554 - lr: 0.0100
# Epoch 14/100
# 1510/1636 [==========================>...] - ETA: 0s - loss: 0.1556 - accuracy: 0.9550
# Epoch 14: loss did not improve from 0.15798
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.007999999821186066.
# 1636/1636 [==============================] - 0s 302us/step - loss: 0.1587 - accuracy: 0.9546 - lr: 0.0100
# Epoch 15/100
# 1605/1636 [============================>.] - ETA: 0s - loss: 0.1582 - accuracy: 0.9547
# Epoch 15: loss improved from 0.15798 to 0.15651, saving model to Models/015-0.1565-0.9554.hdf5
# 1636/1636 [==============================] - 1s 360us/step - loss: 0.1565 - accuracy: 0.9554 - lr: 0.0080
# Epoch 16/100
# 1473/1636 [==========================>...] - ETA: 0s - loss: 0.1607 - accuracy: 0.9541
# Epoch 16: loss improved from 0.15651 to 0.15542, saving model to Models/016-0.1554-0.9562.hdf5
# 1636/1636 [==============================] - 1s 311us/step - loss: 0.1554 - accuracy: 0.9562 - lr: 0.0080
# Epoch 17/100
# 1498/1636 [==========================>...] - ETA: 0s - loss: 0.1575 - accuracy: 0.9542
# Epoch 17: loss did not improve from 0.15542
# 1636/1636 [==============================] - 0s 302us/step - loss: 0.1572 - accuracy: 0.9542 - lr: 0.0080
# Epoch 18/100
# 1532/1636 [===========================>..] - ETA: 0s - loss: 0.1585 - accuracy: 0.9541
# Epoch 18: loss did not improve from 0.15542
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1604 - accuracy: 0.9531 - lr: 0.0080
# Epoch 19/100
# 1576/1636 [===========================>..] - ETA: 0s - loss: 0.1544 - accuracy: 0.9562
# Epoch 19: loss improved from 0.15542 to 0.15420, saving model to Models/019-0.1542-0.9556.hdf5
# 1636/1636 [==============================] - 1s 323us/step - loss: 0.1542 - accuracy: 0.9556 - lr: 0.0080
# Epoch 20/100
# 1547/1636 [===========================>..] - ETA: 0s - loss: 0.1582 - accuracy: 0.9545
# Epoch 20: loss did not improve from 0.15420
# 1636/1636 [==============================] - 1s 324us/step - loss: 0.1573 - accuracy: 0.9550 - lr: 0.0080
# Epoch 21/100
# 1560/1636 [===========================>..] - ETA: 0s - loss: 0.1552 - accuracy: 0.9560
# Epoch 21: loss improved from 0.15420 to 0.15335, saving model to Models/021-0.1534-0.9566.hdf5
# 1636/1636 [==============================] - 1s 327us/step - loss: 0.1534 - accuracy: 0.9566 - lr: 0.0080
# Epoch 22/100
# 1622/1636 [============================>.] - ETA: 0s - loss: 0.1558 - accuracy: 0.9548
# Epoch 22: loss did not improve from 0.15335
# 1636/1636 [==============================] - 1s 310us/step - loss: 0.1554 - accuracy: 0.9550 - lr: 0.0080
# Epoch 23/100
# 1620/1636 [============================>.] - ETA: 0s - loss: 0.1565 - accuracy: 0.9553
# Epoch 23: loss did not improve from 0.15335
# 1636/1636 [==============================] - 1s 310us/step - loss: 0.1573 - accuracy: 0.9548 - lr: 0.0080
# Epoch 24/100
# 1530/1636 [===========================>..] - ETA: 0s - loss: 0.1567 - accuracy: 0.9564
# Epoch 24: loss did not improve from 0.15335
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.006399999558925629.
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1554 - accuracy: 0.9568 - lr: 0.0080
# Epoch 25/100
# 1522/1636 [==========================>...] - ETA: 0s - loss: 0.1527 - accuracy: 0.9547
# Epoch 25: loss improved from 0.15335 to 0.15088, saving model to Models/025-0.1509-0.9554.hdf5
# 1636/1636 [==============================] - 0s 302us/step - loss: 0.1509 - accuracy: 0.9554 - lr: 0.0064
# Epoch 26/100
# 1524/1636 [==========================>...] - ETA: 0s - loss: 0.1526 - accuracy: 0.9573
# Epoch 26: loss did not improve from 0.15088
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1530 - accuracy: 0.9572 - lr: 0.0064
# Epoch 27/100
# 1522/1636 [==========================>...] - ETA: 0s - loss: 0.1503 - accuracy: 0.9562
# Epoch 27: loss did not improve from 0.15088
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1516 - accuracy: 0.9558 - lr: 0.0064
# Epoch 28/100
# 1636/1636 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9568
# Epoch 28: loss did not improve from 0.15088
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0051199994981288915.
# 1636/1636 [==============================] - 1s 307us/step - loss: 0.1517 - accuracy: 0.9568 - lr: 0.0064
# Epoch 29/100
# 1522/1636 [==========================>...] - ETA: 0s - loss: 0.1465 - accuracy: 0.9588
# Epoch 29: loss did not improve from 0.15088
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1509 - accuracy: 0.9562 - lr: 0.0051
# Epoch 30/100
# 1523/1636 [==========================>...] - ETA: 0s - loss: 0.1478 - accuracy: 0.9564
# Epoch 30: loss improved from 0.15088 to 0.14750, saving model to Models/030-0.1475-0.9568.hdf5
# 1636/1636 [==============================] - 0s 301us/step - loss: 0.1475 - accuracy: 0.9568 - lr: 0.0051
# Epoch 31/100
# 1511/1636 [==========================>...] - ETA: 0s - loss: 0.1502 - accuracy: 0.9565
# Epoch 31: loss did not improve from 0.14750
# 1636/1636 [==============================] - 0s 300us/step - loss: 0.1505 - accuracy: 0.9566 - lr: 0.0051
# Epoch 32/100
# 1504/1636 [==========================>...] - ETA: 0s - loss: 0.1477 - accuracy: 0.9568
# Epoch 32: loss did not improve from 0.14750
# 1636/1636 [==============================] - 0s 301us/step - loss: 0.1495 - accuracy: 0.9560 - lr: 0.0051
# Epoch 33/100
# 1520/1636 [==========================>...] - ETA: 0s - loss: 0.1450 - accuracy: 0.9583
# Epoch 33: loss did not improve from 0.14750
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.004095999523997307.
# 1636/1636 [==============================] - 0s 302us/step - loss: 0.1508 - accuracy: 0.9570 - lr: 0.0051
# Epoch 34/100
# 1536/1636 [===========================>..] - ETA: 0s - loss: 0.1476 - accuracy: 0.9570
# Epoch 34: loss did not improve from 0.14750
# 1636/1636 [==============================] - 0s 295us/step - loss: 0.1484 - accuracy: 0.9564 - lr: 0.0041
# Epoch 35/100
# 1530/1636 [===========================>..] - ETA: 0s - loss: 0.1453 - accuracy: 0.9566
# Epoch 35: loss improved from 0.14750 to 0.14731, saving model to Models/035-0.1473-0.9558.hdf5
# 1636/1636 [==============================] - 0s 300us/step - loss: 0.1473 - accuracy: 0.9558 - lr: 0.0041
# Epoch 36/100
# 1516/1636 [==========================>...] - ETA: 0s - loss: 0.1488 - accuracy: 0.9558
# Epoch 36: loss did not improve from 0.14731
# 1636/1636 [==============================] - 0s 298us/step - loss: 0.1480 - accuracy: 0.9564 - lr: 0.0041
# Epoch 37/100
# 1531/1636 [===========================>..] - ETA: 0s - loss: 0.1492 - accuracy: 0.9567
# Epoch 37: loss did not improve from 0.14731
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1479 - accuracy: 0.9572 - lr: 0.0041
# Epoch 38/100
# 1533/1636 [===========================>..] - ETA: 0s - loss: 0.1499 - accuracy: 0.9554
# Epoch 38: loss improved from 0.14731 to 0.14628, saving model to Models/038-0.1463-0.9568.hdf5
# 1636/1636 [==============================] - 0s 300us/step - loss: 0.1463 - accuracy: 0.9568 - lr: 0.0041
# Epoch 39/100
# 1532/1636 [===========================>..] - ETA: 0s - loss: 0.1494 - accuracy: 0.9550
# Epoch 39: loss did not improve from 0.14628
# 1636/1636 [==============================] - 0s 295us/step - loss: 0.1477 - accuracy: 0.9558 - lr: 0.0041
# Epoch 40/100
# 1530/1636 [===========================>..] - ETA: 0s - loss: 0.1464 - accuracy: 0.9571
# Epoch 40: loss did not improve from 0.14628
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1485 - accuracy: 0.9564 - lr: 0.0041
# Epoch 41/100
# 1522/1636 [==========================>...] - ETA: 0s - loss: 0.1467 - accuracy: 0.9558
# Epoch 41: loss did not improve from 0.14628
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0032767996191978457.
# 1636/1636 [==============================] - 0s 298us/step - loss: 0.1467 - accuracy: 0.9560 - lr: 0.0041
# Epoch 42/100
# 1504/1636 [==========================>...] - ETA: 0s - loss: 0.1461 - accuracy: 0.9561
# Epoch 42: loss improved from 0.14628 to 0.14581, saving model to Models/042-0.1458-0.9566.hdf5
# 1636/1636 [==============================] - 0s 305us/step - loss: 0.1458 - accuracy: 0.9566 - lr: 0.0033
# Epoch 43/100
# 1482/1636 [==========================>...] - ETA: 0s - loss: 0.1496 - accuracy: 0.9550
# Epoch 43: loss did not improve from 0.14581
# 1636/1636 [==============================] - 0s 304us/step - loss: 0.1460 - accuracy: 0.9564 - lr: 0.0033
# Epoch 44/100
# 1524/1636 [==========================>...] - ETA: 0s - loss: 0.1474 - accuracy: 0.9534
# Epoch 44: loss improved from 0.14581 to 0.14466, saving model to Models/044-0.1447-0.9550.hdf5
# 1636/1636 [==============================] - 0s 301us/step - loss: 0.1447 - accuracy: 0.9550 - lr: 0.0033
# Epoch 45/100
# 1527/1636 [===========================>..] - ETA: 0s - loss: 0.1446 - accuracy: 0.9559
# Epoch 45: loss did not improve from 0.14466
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1456 - accuracy: 0.9560 - lr: 0.0033
# Epoch 46/100
# 1531/1636 [===========================>..] - ETA: 0s - loss: 0.1481 - accuracy: 0.9558
# Epoch 46: loss did not improve from 0.14466
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1455 - accuracy: 0.9568 - lr: 0.0033
# Epoch 47/100
# 1527/1636 [===========================>..] - ETA: 0s - loss: 0.1443 - accuracy: 0.9572
# Epoch 47: loss did not improve from 0.14466
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0026214396581053737.
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1463 - accuracy: 0.9560 - lr: 0.0033
# Epoch 48/100
# 1513/1636 [==========================>...] - ETA: 0s - loss: 0.1437 - accuracy: 0.9579
# Epoch 48: loss improved from 0.14466 to 0.14465, saving model to Models/048-0.1447-0.9572.hdf5
# 1636/1636 [==============================] - 0s 303us/step - loss: 0.1447 - accuracy: 0.9572 - lr: 0.0026
# Epoch 49/100
# 1526/1636 [==========================>...] - ETA: 0s - loss: 0.1455 - accuracy: 0.9565
# Epoch 49: loss did not improve from 0.14465
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1449 - accuracy: 0.9566 - lr: 0.0026
# Epoch 50/100
# 1533/1636 [===========================>..] - ETA: 0s - loss: 0.1472 - accuracy: 0.9548
# Epoch 50: loss did not improve from 0.14465
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0020971518009901048.
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1449 - accuracy: 0.9558 - lr: 0.0026
# Epoch 51/100
# 1515/1636 [==========================>...] - ETA: 0s - loss: 0.1437 - accuracy: 0.9575
# Epoch 51: loss improved from 0.14465 to 0.14357, saving model to Models/051-0.1436-0.9576.hdf5
# 1636/1636 [==============================] - 0s 303us/step - loss: 0.1436 - accuracy: 0.9576 - lr: 0.0021
# Epoch 52/100
# 1521/1636 [==========================>...] - ETA: 0s - loss: 0.1417 - accuracy: 0.9575
# Epoch 52: loss did not improve from 0.14357
# 1636/1636 [==============================] - 0s 298us/step - loss: 0.1439 - accuracy: 0.9566 - lr: 0.0021
# Epoch 53/100
# 1516/1636 [==========================>...] - ETA: 0s - loss: 0.1393 - accuracy: 0.9595
# Epoch 53: loss improved from 0.14357 to 0.14275, saving model to Models/053-0.1427-0.9574.hdf5
# 1636/1636 [==============================] - 0s 303us/step - loss: 0.1427 - accuracy: 0.9574 - lr: 0.0021
# Epoch 54/100
# 1529/1636 [===========================>..] - ETA: 0s - loss: 0.1447 - accuracy: 0.9577
# Epoch 54: loss did not improve from 0.14275
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1439 - accuracy: 0.9576 - lr: 0.0021
# Epoch 55/100
# 1531/1636 [===========================>..] - ETA: 0s - loss: 0.1454 - accuracy: 0.9560
# Epoch 55: loss did not improve from 0.14275
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1438 - accuracy: 0.9564 - lr: 0.0021
# Epoch 56/100
# 1527/1636 [===========================>..] - ETA: 0s - loss: 0.1447 - accuracy: 0.9568
# Epoch 56: loss did not improve from 0.14275
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0016777213662862779.
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1443 - accuracy: 0.9568 - lr: 0.0021
# Epoch 57/100
# 1517/1636 [==========================>...] - ETA: 0s - loss: 0.1422 - accuracy: 0.9574
# Epoch 57: loss did not improve from 0.14275
# 1636/1636 [==============================] - 0s 298us/step - loss: 0.1429 - accuracy: 0.9574 - lr: 0.0017
# Epoch 58/100
# 1511/1636 [==========================>...] - ETA: 0s - loss: 0.1414 - accuracy: 0.9574
# Epoch 58: loss did not improve from 0.14275
# 1636/1636 [==============================] - 0s 299us/step - loss: 0.1438 - accuracy: 0.9572 - lr: 0.0017
# Epoch 59/100
# 1497/1636 [==========================>...] - ETA: 0s - loss: 0.1427 - accuracy: 0.9570
# Epoch 59: loss improved from 0.14275 to 0.14264, saving model to Models/059-0.1426-0.9572.hdf5
# 1636/1636 [==============================] - 1s 307us/step - loss: 0.1426 - accuracy: 0.9572 - lr: 0.0017
# Epoch 60/100
# 1634/1636 [============================>.] - ETA: 0s - loss: 0.1436 - accuracy: 0.9570
# Epoch 60: loss did not improve from 0.14264
# 1636/1636 [==============================] - 1s 307us/step - loss: 0.1435 - accuracy: 0.9570 - lr: 0.0017
# Epoch 61/100
# 1495/1636 [==========================>...] - ETA: 0s - loss: 0.1416 - accuracy: 0.9576
# Epoch 61: loss did not improve from 0.14264
# 1636/1636 [==============================] - 0s 302us/step - loss: 0.1438 - accuracy: 0.9568 - lr: 0.0017
# Epoch 62/100
# 1518/1636 [==========================>...] - ETA: 0s - loss: 0.1480 - accuracy: 0.9541
# Epoch 62: loss did not improve from 0.14264
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0013421771116554739.
# 1636/1636 [==============================] - 0s 298us/step - loss: 0.1431 - accuracy: 0.9562 - lr: 0.0017
# Epoch 63/100
# 1532/1636 [===========================>..] - ETA: 0s - loss: 0.1437 - accuracy: 0.9558
# Epoch 63: loss did not improve from 0.14264
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1432 - accuracy: 0.9562 - lr: 0.0013
# Epoch 64/100
# 1525/1636 [==========================>...] - ETA: 0s - loss: 0.1415 - accuracy: 0.9563
# Epoch 64: loss did not improve from 0.14264
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1429 - accuracy: 0.9562 - lr: 0.0013
# Epoch 65/100
# 1522/1636 [==========================>...] - ETA: 0s - loss: 0.1426 - accuracy: 0.9573
# Epoch 65: loss did not improve from 0.14264
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 0.001073741726577282.
# 1636/1636 [==============================] - 0s 298us/step - loss: 0.1431 - accuracy: 0.9570 - lr: 0.0013
# Epoch 66/100
# 1500/1636 [==========================>...] - ETA: 0s - loss: 0.1421 - accuracy: 0.9573
# Epoch 66: loss improved from 0.14264 to 0.14234, saving model to Models/066-0.1423-0.9574.hdf5
# 1636/1636 [==============================] - 1s 306us/step - loss: 0.1423 - accuracy: 0.9574 - lr: 0.0011
# Epoch 67/100
# 1533/1636 [===========================>..] - ETA: 0s - loss: 0.1435 - accuracy: 0.9572
# Epoch 67: loss improved from 0.14234 to 0.14186, saving model to Models/067-0.1419-0.9572.hdf5
# 1636/1636 [==============================] - 0s 300us/step - loss: 0.1419 - accuracy: 0.9572 - lr: 0.0011
# Epoch 68/100
# 1527/1636 [===========================>..] - ETA: 0s - loss: 0.1431 - accuracy: 0.9568
# Epoch 68: loss did not improve from 0.14186
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1426 - accuracy: 0.9574 - lr: 0.0011
# Epoch 69/100
# 1522/1636 [==========================>...] - ETA: 0s - loss: 0.1425 - accuracy: 0.9573
# Epoch 69: loss did not improve from 0.14186
# 1636/1636 [==============================] - 0s 298us/step - loss: 0.1423 - accuracy: 0.9574 - lr: 0.0011
# Epoch 70/100
# 1513/1636 [==========================>...] - ETA: 0s - loss: 0.1428 - accuracy: 0.9568
# Epoch 70: loss did not improve from 0.14186
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.0008589933626353742.
# 1636/1636 [==============================] - 0s 299us/step - loss: 0.1424 - accuracy: 0.9568 - lr: 0.0011
# Epoch 71/100
# 1513/1636 [==========================>...] - ETA: 0s - loss: 0.1399 - accuracy: 0.9586
# Epoch 71: loss improved from 0.14186 to 0.14167, saving model to Models/071-0.1417-0.9578.hdf5
# 1636/1636 [==============================] - 0s 303us/step - loss: 0.1417 - accuracy: 0.9578 - lr: 8.5899e-04
# Epoch 72/100
# 1527/1636 [===========================>..] - ETA: 0s - loss: 0.1424 - accuracy: 0.9579
# Epoch 72: loss did not improve from 0.14167
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1418 - accuracy: 0.9576 - lr: 8.5899e-04
# Epoch 73/100
# 1474/1636 [==========================>...] - ETA: 0s - loss: 0.1412 - accuracy: 0.9584
# Epoch 73: loss improved from 0.14167 to 0.14166, saving model to Models/073-0.1417-0.9574.hdf5
# 1636/1636 [==============================] - 1s 310us/step - loss: 0.1417 - accuracy: 0.9574 - lr: 8.5899e-04
# Epoch 74/100
# 1515/1636 [==========================>...] - ETA: 0s - loss: 0.1428 - accuracy: 0.9582
# Epoch 74: loss did not improve from 0.14166
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0006871947087347508.
# 1636/1636 [==============================] - 0s 298us/step - loss: 0.1424 - accuracy: 0.9580 - lr: 8.5899e-04
# Epoch 75/100
# 1535/1636 [===========================>..] - ETA: 0s - loss: 0.1444 - accuracy: 0.9564
# Epoch 75: loss improved from 0.14166 to 0.14161, saving model to Models/075-0.1416-0.9572.hdf5
# 1636/1636 [==============================] - 0s 299us/step - loss: 0.1416 - accuracy: 0.9572 - lr: 6.8719e-04
# Epoch 76/100
# 1529/1636 [===========================>..] - ETA: 0s - loss: 0.1388 - accuracy: 0.9586
# Epoch 76: loss improved from 0.14161 to 0.14144, saving model to Models/076-0.1414-0.9572.hdf5
# 1636/1636 [==============================] - 0s 300us/step - loss: 0.1414 - accuracy: 0.9572 - lr: 6.8719e-04
# Epoch 77/100
# 1517/1636 [==========================>...] - ETA: 0s - loss: 0.1408 - accuracy: 0.9576
# Epoch 77: loss did not improve from 0.14144
# 1636/1636 [==============================] - 0s 298us/step - loss: 0.1416 - accuracy: 0.9574 - lr: 6.8719e-04
# Epoch 78/100
# 1523/1636 [==========================>...] - ETA: 0s - loss: 0.1408 - accuracy: 0.9578
# Epoch 78: loss did not improve from 0.14144
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1419 - accuracy: 0.9574 - lr: 6.8719e-04
# Epoch 79/100
# 1523/1636 [==========================>...] - ETA: 0s - loss: 0.1397 - accuracy: 0.9575
# Epoch 79: loss did not improve from 0.14144
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.0005497557576745749.
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1417 - accuracy: 0.9572 - lr: 6.8719e-04
# Epoch 80/100
# 1519/1636 [==========================>...] - ETA: 0s - loss: 0.1429 - accuracy: 0.9566
# Epoch 80: loss improved from 0.14144 to 0.14123, saving model to Models/080-0.1412-0.9574.hdf5
# 1636/1636 [==============================] - 0s 305us/step - loss: 0.1412 - accuracy: 0.9574 - lr: 5.4976e-04
# Epoch 81/100
# 1531/1636 [===========================>..] - ETA: 0s - loss: 0.1354 - accuracy: 0.9595
# Epoch 81: loss did not improve from 0.14123
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1415 - accuracy: 0.9576 - lr: 5.4976e-04
# Epoch 82/100
# 1527/1636 [===========================>..] - ETA: 0s - loss: 0.1417 - accuracy: 0.9574
# Epoch 82: loss did not improve from 0.14123
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1414 - accuracy: 0.9576 - lr: 5.4976e-04
# Epoch 83/100
# 1532/1636 [===========================>..] - ETA: 0s - loss: 0.1383 - accuracy: 0.9580
# Epoch 83: loss improved from 0.14123 to 0.14122, saving model to Models/083-0.1412-0.9570.hdf5
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 0.0004398046061396599.
# 1636/1636 [==============================] - 0s 301us/step - loss: 0.1412 - accuracy: 0.9570 - lr: 5.4976e-04
# Epoch 84/100
# 1505/1636 [==========================>...] - ETA: 0s - loss: 0.1364 - accuracy: 0.9595
# Epoch 84: loss improved from 0.14122 to 0.14087, saving model to Models/084-0.1409-0.9574.hdf5
# 1636/1636 [==============================] - 0s 304us/step - loss: 0.1409 - accuracy: 0.9574 - lr: 4.3980e-04
# Epoch 85/100
# 1541/1636 [===========================>..] - ETA: 0s - loss: 0.1422 - accuracy: 0.9574
# Epoch 85: loss did not improve from 0.14087
# 1636/1636 [==============================] - 0s 294us/step - loss: 0.1412 - accuracy: 0.9578 - lr: 4.3980e-04
# Epoch 86/100
# 1530/1636 [===========================>..] - ETA: 0s - loss: 0.1418 - accuracy: 0.9566
# Epoch 86: loss did not improve from 0.14087
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1413 - accuracy: 0.9570 - lr: 4.3980e-04
# Epoch 87/100
# 1524/1636 [==========================>...] - ETA: 0s - loss: 0.1384 - accuracy: 0.9584
# Epoch 87: loss did not improve from 0.14087
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 0.00035184368025511505.
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1411 - accuracy: 0.9574 - lr: 4.3980e-04
# Epoch 88/100
# 1522/1636 [==========================>...] - ETA: 0s - loss: 0.1431 - accuracy: 0.9571
# Epoch 88: loss did not improve from 0.14087
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1410 - accuracy: 0.9576 - lr: 3.5184e-04
# Epoch 89/100
# 1523/1636 [==========================>...] - ETA: 0s - loss: 0.1395 - accuracy: 0.9582
# Epoch 89: loss did not improve from 0.14087
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1412 - accuracy: 0.9574 - lr: 3.5184e-04
# Epoch 90/100
# 1497/1636 [==========================>...] - ETA: 0s - loss: 0.1411 - accuracy: 0.9570
# Epoch 90: loss did not improve from 0.14087
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 0.0002814749488607049.
# 1636/1636 [==============================] - 0s 302us/step - loss: 0.1410 - accuracy: 0.9570 - lr: 3.5184e-04
# Epoch 91/100
# 1520/1636 [==========================>...] - ETA: 0s - loss: 0.1410 - accuracy: 0.9575
# Epoch 91: loss improved from 0.14087 to 0.14072, saving model to Models/091-0.1407-0.9576.hdf5
# 1636/1636 [==============================] - 0s 302us/step - loss: 0.1407 - accuracy: 0.9576 - lr: 2.8147e-04
# Epoch 92/100
# 1524/1636 [==========================>...] - ETA: 0s - loss: 0.1413 - accuracy: 0.9571
# Epoch 92: loss did not improve from 0.14072
# 1636/1636 [==============================] - 0s 297us/step - loss: 0.1408 - accuracy: 0.9576 - lr: 2.8147e-04
# Epoch 93/100
# 1514/1636 [==========================>...] - ETA: 0s - loss: 0.1383 - accuracy: 0.9590
# Epoch 93: loss did not improve from 0.14072
# 1636/1636 [==============================] - 0s 299us/step - loss: 0.1409 - accuracy: 0.9576 - lr: 2.8147e-04
# Epoch 94/100
# 1531/1636 [===========================>..] - ETA: 0s - loss: 0.1406 - accuracy: 0.9575
# Epoch 94: loss did not improve from 0.14072
#
# Epoch 94: ReduceLROnPlateau reducing learning rate to 0.0002251799684017897.
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1409 - accuracy: 0.9574 - lr: 2.8147e-04
# Epoch 95/100
# 1520/1636 [==========================>...] - ETA: 0s - loss: 0.1385 - accuracy: 0.9588
# Epoch 95: loss improved from 0.14072 to 0.14061, saving model to Models/095-0.1406-0.9578.hdf5
# 1636/1636 [==============================] - 0s 302us/step - loss: 0.1406 - accuracy: 0.9578 - lr: 2.2518e-04
# Epoch 96/100
# 1507/1636 [==========================>...] - ETA: 0s - loss: 0.1452 - accuracy: 0.9562
# Epoch 96: loss improved from 0.14061 to 0.14058, saving model to Models/096-0.1406-0.9576.hdf5
# 1636/1636 [==============================] - 0s 304us/step - loss: 0.1406 - accuracy: 0.9576 - lr: 2.2518e-04
# Epoch 97/100
# 1527/1636 [===========================>..] - ETA: 0s - loss: 0.1419 - accuracy: 0.9572
# Epoch 97: loss did not improve from 0.14058
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1408 - accuracy: 0.9572 - lr: 2.2518e-04
# Epoch 98/100
# 1531/1636 [===========================>..] - ETA: 0s - loss: 0.1404 - accuracy: 0.9575
# Epoch 98: loss did not improve from 0.14058
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 0.0001801439793780446.
# 1636/1636 [==============================] - 0s 296us/step - loss: 0.1407 - accuracy: 0.9574 - lr: 2.2518e-04
# Epoch 99/100
# 1514/1636 [==========================>...] - ETA: 0s - loss: 0.1422 - accuracy: 0.9568
# Epoch 99: loss improved from 0.14058 to 0.14052, saving model to Models/099-0.1405-0.9576.hdf5
# 1636/1636 [==============================] - 0s 303us/step - loss: 0.1405 - accuracy: 0.9576 - lr: 1.8014e-04
# Epoch 100/100
# 1487/1636 [==========================>...] - ETA: 0s - loss: 0.1421 - accuracy: 0.9567
# Epoch 100: loss did not improve from 0.14052
# 1636/1636 [==============================] - 0s 304us/step - loss: 0.1407 - accuracy: 0.9574 - lr: 1.8014e-04

# %% [markdown]
# # Model Load 하기 전, hdf5 파일 이름 꼭 확인하기

# %%
model.load_weights("Models/099-0.1405-0.9576.hdf5")

# %% [markdown]
# ## FLASK 셋팅하기

# %%
from flask import Flask
from flask import render_template
from flask import request
import pandas as pd

# %%
app = Flask(__name__)

# %% [markdown]
# # FLASK API 구현부분

# %%
@app.route('/')
@app.route('/Stroke')
def StrokePrediction():
    gender = request.args.get("gender")
    age = request.args.get("age")
    hypertension = request.args.get("hypertension")
    heart_disease = request.args.get("heart_disease")
    ever_married= request.args.get("ever_married")
    avg_glucose_level = request.args.get("avg_glucose_level")
    bmi = request.args.get("bmi")
    smoking_status = request.args.get("smoking_status")

    if gender == None or age == None:
        return render_template('index.html', Output = '')
    
    Input = pd.DataFrame({
        'gender': [ float(gender) ],
        'age': [ float(age) ],
        'hypertension': [ float(hypertension) ],
        'heart_disease': [ float(heart_disease) ],
        'ever_married': [ float(ever_married) ],
        'avg_glucose_level': [ float(avg_glucose_level) ],
        'bmi': [ float(bmi) ],
        'smoking_status': [float(smoking_status)]
    })
    ModelOutput = model.predict(Input)[0][0]

    return render_template('Stroke.html', Output = ModelOutput * 100 )

# %% [markdown]
# # Flask, port 5000으로 실행

# %%
app.run(host='0.0.0.0', port=5001)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses (0.0.0.0)
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://127.0.0.1:5001
#  * Running on http://10.186.24.41:5001 (Press CTRL+C to quit)

# %%
# http://127.0.0.1:5000/SpecialSale/1/38
